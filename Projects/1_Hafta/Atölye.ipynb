# %% [markdown]
# **Basket Dataset**

# %%
import pandas as pd

# %%
df_1 = pd.read_csv("D:\\Kütüphane\\YZT Kamp\\YZT KAMP G26\\Mid+\\Yeni\\Atölye Proje\\customer_details.csv")

# %%
df_2 = pd.read_csv("D:\\Kütüphane\\YZT Kamp\\YZT KAMP G26\\Mid+\\Yeni\\Atölye Proje\\basket_details.csv")

# %%
df_1.head()
# Out:
#    customer_id   sex  customer_age  tenure
# 0      9798859  Male          44.0      93
# 1     11413563  Male          36.0      65
# 2       818195  Male          35.0     129
# 3     12049009  Male          33.0      58
# 4     10083045  Male          42.0      88

# %%
print(df_1.info)
print(df_1.describe(include="all"))
print(df_1.head())
# Out:
# <bound method DataFrame.info of        customer_id   sex  customer_age  tenure
# 0          9798859  Male          44.0      93
# 1         11413563  Male          36.0      65
# 2           818195  Male          35.0     129
# 3         12049009  Male          33.0      58
# 4         10083045  Male          42.0      88
# ...            ...   ...           ...     ...
# 19995     12557307  Male          41.0      52
# 19996     12595961  Male          29.0      52
# 19997     12520991  Male          35.0      52
# 19998     12612719  Male          39.0      52
# 19999     12572063  Male          28.0      52
#
# [20000 rows x 4 columns]>
#          customer_id    sex  customer_age        tenure
# count   2.000000e+04  20000  20000.000000  20000.000000
# unique           NaN      4           NaN           NaN
# top              NaN   Male           NaN           NaN
# freq             NaN  15322           NaN           NaN
# mean    1.760040e+07    NaN    262.222550     44.396800
# ...

# %%
df_1 = df_1.drop(columns = ["customer_id"])

# %%
df_1["sex"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df_1 = df_1[df_1['sex'].isin(['Male', 'Female'])]

# %%
df_1["sex"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df_1 = df_1.dropna()

# %%
df_1.isna().sum()
# Out:
# sex             0
# customer_age    0
# tenure          0
# dtype: int64

# %%
pd.get_dummies(df_1, columns = ["sex"])
# Out:
#        customer_age  tenure  sex_Female  sex_Male  sex_UNKNOWN  \
# 0              44.0      93       False      True        False
# 1              36.0      65       False      True        False
# 2              35.0     129       False      True        False
# 3              33.0      58       False      True        False
# 4              42.0      88       False      True        False
# ...             ...     ...         ...       ...          ...
# 19995          41.0      52       False      True        False
# 19996          29.0      52       False      True        False
# 19997          35.0      52       False      True        False
# 19998          39.0      52       False      True        False
# 19999          28.0      52       False      True        False
#
#        sex_kvkktalepsilindi
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# ...                     ...
# ...

# %%
plt.figure(figsize=(8,6))
plt.scatter(df_1['customer_age'], df_1['tenure'], alpha=0.6, color='green')
plt.title('Customer Age vs Tenure')
plt.xlabel('Customer Age')
plt.ylabel('Tenure')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
plt.scatter(df['customer_age'], df['tenure'], color='blue', alpha=0.6)
plt.title('Customer Age vs Tenure')
plt.xlabel('Customer Age')
plt.ylabel('Tenure')
plt.grid(True)

# Eksenleri veri aralığına göre sınırla
plt.xlim(20, 50)   # x ekseni sadece yaş dağılımı
plt.ylim(50, 130)  # y ekseni sadece tenure

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
plt.scatter(df['customer_age'], df['tenure'], alpha=0.6, color='teal')
plt.title('Customer Age vs Tenure')
plt.xlabel('Customer Age')
plt.ylabel('Tenure')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# -----

# %%
df_2.head()
# Out:
#    customer_id  product_id basket_date  basket_count
# 0     42366585    41475073  2019-06-19             2
# 1     35956841    43279538  2019-06-19             2
# 2     26139578    31715598  2019-06-19             3
# 3      3262253    47880260  2019-06-19             2
# 4     20056678    44747002  2019-06-19             2

# %%
df_2.info
# Out:
# <bound method DataFrame.info of        customer_id  product_id basket_date  basket_count
# 0         42366585    41475073  2019-06-19             2
# 1         35956841    43279538  2019-06-19             2
# 2         26139578    31715598  2019-06-19             3
# 3          3262253    47880260  2019-06-19             2
# 4         20056678    44747002  2019-06-19             2
# ...            ...         ...         ...           ...
# 14995      8336862    50977318  2019-05-26             2
# 14996      9500785    43862061  2019-05-26             2
# 14997     22787344     6041664  2019-05-26             2
# 14998      8221263     3597369  2019-05-26             2
# 14999      4912577    46646893  2019-05-26             2
#
# [15000 rows x 4 columns]>

# %%
df_2["customer_id"].nunique()
# Out:
# 13871

# %%
df_2.isna().sum()
# Out:
# customer_id     0
# product_id      0
# basket_date     0
# basket_count    0
# dtype: int64

# %%
df_2.info
# Out:
# <bound method DataFrame.info of        customer_id  product_id basket_date  basket_count
# 0         42366585    41475073  2019-06-19             2
# 1         35956841    43279538  2019-06-19             2
# 2         26139578    31715598  2019-06-19             3
# 3          3262253    47880260  2019-06-19             2
# 4         20056678    44747002  2019-06-19             2
# ...            ...         ...         ...           ...
# 14995      8336862    50977318  2019-05-26             2
# 14996      9500785    43862061  2019-05-26             2
# 14997     22787344     6041664  2019-05-26             2
# 14998      8221263     3597369  2019-05-26             2
# 14999      4912577    46646893  2019-05-26             2
#
# [15000 rows x 4 columns]>

# %% [markdown]
# ---------

# %% [markdown]
# **Machine Learning**

# %%
df_1
# Out:
#         sex  customer_age  tenure
# 0      Male          44.0      93
# 1      Male          36.0      65
# 2      Male          35.0     129
# 3      Male          33.0      58
# 4      Male          42.0      88
# ...     ...           ...     ...
# 19995  Male          41.0      52
# 19996  Male          29.0      52
# 19997  Male          35.0      52
# 19998  Male          39.0      52
# 19999  Male          28.0      52
#
# [20000 rows x 3 columns]

# %%
df_2
# Out:
#        customer_id  product_id basket_date  basket_count
# 0         42366585    41475073  2019-06-19             2
# 1         35956841    43279538  2019-06-19             2
# 2         26139578    31715598  2019-06-19             3
# 3          3262253    47880260  2019-06-19             2
# 4         20056678    44747002  2019-06-19             2
# ...            ...         ...         ...           ...
# 14995      8336862    50977318  2019-05-26             2
# 14996      9500785    43862061  2019-05-26             2
# 14997     22787344     6041664  2019-05-26             2
# 14998      8221263     3597369  2019-05-26             2
# 14999      4912577    46646893  2019-05-26             2
#
# [15000 rows x 4 columns]

# %%
x = df_1[["customer_age", "tenure"]]
y = df_2["basket_count"]

# %%
X = x.reset_index(drop=True)
Y = y.reset_index(drop=True)

# %%
from sklearn.model_selection import train_test_split

# %%
df_combined = X.join(Y, how='inner')  # sadece ortak indeksler

x_train, x_test, y_train, y_test = train_test_split(
    df_combined[['customer_age']], df_combined['tenure'], test_size=0.2, random_state=42
)

# %%
df_combined
# Out:
#        customer_age  tenure  basket_count
# 0              44.0      93             2
# 1              36.0      65             2
# 2              35.0     129             3
# 3              33.0      58             2
# 4              42.0      88             2
# ...             ...     ...           ...
# 14995          29.0      33             2
# 14996          38.0      33             2
# 14997          22.0      33             2
# 14998           5.0      33             2
# 14999        2022.0      33             2
#
# [15000 rows x 3 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

LM = LinearRegression()
Model = LM.fit(x_train, y_train)
Model.score(x_test,y_test)
# Out:
# 0.009394400325777874

# %% [markdown]
# -------

# %% [markdown]
# **Data Analysis**

# %%
df_1 = pd.read_csv("D:\\Kütüphane\\YZT Kamp\\YZT KAMP G26\\Mid+\\Yeni\\Atölye Proje\\customer_details.csv")

# %%
df_2 = pd.read_csv("D:\\Kütüphane\\YZT Kamp\\YZT KAMP G26\\Mid+\\Yeni\\Atölye Proje\\basket_details.csv")

# %%
df_1.head()
# Out:
#    customer_id   sex  customer_age  tenure
# 0      9798859  Male          44.0      93
# 1     11413563  Male          36.0      65
# 2       818195  Male          35.0     129
# 3     12049009  Male          33.0      58
# 4     10083045  Male          42.0      88

# %%
df_2.head()
# Out:
#    customer_id  product_id basket_date  basket_count
# 0     42366585    41475073  2019-06-19             2
# 1     35956841    43279538  2019-06-19             2
# 2     26139578    31715598  2019-06-19             3
# 3      3262253    47880260  2019-06-19             2
# 4     20056678    44747002  2019-06-19             2

# %%
common_df = pd.merge(df_1 , df_2 , on="customer_id" , how="inner")

# %% [markdown]
# **İki datasetteki 72 satırlık ortak veri var**

# %%
common_df
# Out:
#     customer_id     sex  customer_age  tenure  product_id basket_date  \
# 0       9500953    Male          55.0      96     3446783  2019-06-10
# 1        851739    Male          40.0     129    32920704  2019-06-19
# 2       9654043    Male          37.0      95    51307669  2019-06-08
# 3       4912369    Male          36.0     114    33923115  2019-05-20
# 4       9875271    Male          34.0      92    31586037  2019-06-06
# ..          ...     ...           ...     ...         ...         ...
# 67     13278573    Male          28.0      47     4488682  2019-05-26
# 68     12901520  Female          40.0      50    38610580  2019-05-28
# 69     12737235    Male          39.0      51    32933848  2019-05-21
# 70     12737235    Male          39.0      51    46373374  2019-05-21
# 71     12574807    Male          33.0      52    32056122  2019-05-25
#
#     basket_count
# 0              3
# 1              2
# 2              2
# 3              2
# 4              2
# ...

# %% [markdown]
# **Kaç kız kaç erkek var**

# %%
df_1["sex"].unique()
# Out:
# array(['Male', 'Female', 'kvkktalepsilindi', 'UNKNOWN'], dtype=object)

# %%
df_1 = df_1[df_1['sex'].isin(['Male', 'Female'])]

# %%
df_1
# Out:
#        customer_id   sex  customer_age  tenure
# 0          9798859  Male          44.0      93
# 1         11413563  Male          36.0      65
# 2           818195  Male          35.0     129
# 3         12049009  Male          33.0      58
# 4         10083045  Male          42.0      88
# ...            ...   ...           ...     ...
# 19995     12557307  Male          41.0      52
# 19996     12595961  Male          29.0      52
# 19997     12520991  Male          35.0      52
# 19998     12612719  Male          39.0      52
# 19999     12572063  Male          28.0      52
#
# [19991 rows x 4 columns]

# %%
df_1["sex"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df_1.isna().sum()
# Out:
# customer_id     0
# sex             0
# customer_age    0
# tenure          0
# dtype: int64

# %%
df_1["sex"].value_counts()
# Out:
# sex
# Male      15322
# Female     4669
# Name: count, dtype: int64

# %% [markdown]
# **Kaç farklı ürün var**

# %%
df_2.head()
# Out:
#    customer_id  product_id basket_date  basket_count
# 0     42366585    41475073  2019-06-19             2
# 1     35956841    43279538  2019-06-19             2
# 2     26139578    31715598  2019-06-19             3
# 3      3262253    47880260  2019-06-19             2
# 4     20056678    44747002  2019-06-19             2

# %%
df_2["product_id"].nunique()
# Out:
# 13161

# %% [markdown]
# **Hangi ürün en çok satılmış**

# %%
df_2["product_id"].value_counts()
# Out:
# product_id
# 43524799    32
# 31516269    25
# 39833031    24
# 46130148    17
# 40276011    12
#             ..
# 40160594     1
# 6192154      1
# 4231184      1
# 48559699     1
# 32661392     1
# Name: count, Length: 13161, dtype: int64

# %% [markdown]
# **Kaç farklı müşteri alışveriş yapmış**

# %%
df_2["customer_id"].nunique()
# Out:
# 13871

# %% [markdown]
# **En çok kim vakit geçirmiş**

# %%
df_1["tenure"].value_counts()
# Out:
# tenure
# 27     855
# 15     822
# 39     554
# 38     422
# 40     385
#       ...
# 131     45
# 81      36
# 90      35
# 133      1
# 132      1
# Name: count, Length: 112, dtype: int64

# %% [markdown]
# **En çok kim alışveriş yapmış**

# %%
df_2
# Out:
#        customer_id  product_id basket_date  basket_count
# 0         42366585    41475073  2019-06-19             2
# 1         35956841    43279538  2019-06-19             2
# 2         26139578    31715598  2019-06-19             3
# 3          3262253    47880260  2019-06-19             2
# 4         20056678    44747002  2019-06-19             2
# ...            ...         ...         ...           ...
# 14995      8336862    50977318  2019-05-26             2
# 14996      9500785    43862061  2019-05-26             2
# 14997     22787344     6041664  2019-05-26             2
# 14998      8221263     3597369  2019-05-26             2
# 14999      4912577    46646893  2019-05-26             2
#
# [15000 rows x 4 columns]

# %%
df_2["basket_count"].value_counts()
# Out:
# basket_count
# 2     13323
# 3      1279
# 4       268
# 5        76
# 6        27
# 7        13
# 8        10
# 10        2
# 9         2
# Name: count, dtype: int64

# %% [markdown]
# **Kaç farklı ürün var**

# %%
df_2["product_id"].nunique()
# Out:
# 13161

# %% [markdown]
# **Aynı ürünü kaç kişi almış**

# %%
df_1
# Out:
#        customer_id   sex  customer_age  tenure
# 0          9798859  Male          44.0      93
# 1         11413563  Male          36.0      65
# 2           818195  Male          35.0     129
# 3         12049009  Male          33.0      58
# 4         10083045  Male          42.0      88
# ...            ...   ...           ...     ...
# 19995     12557307  Male          41.0      52
# 19996     12595961  Male          29.0      52
# 19997     12520991  Male          35.0      52
# 19998     12612719  Male          39.0      52
# 19999     12572063  Male          28.0      52
#
# [19991 rows x 4 columns]

# %%
df_2
# Out:
#        customer_id  product_id basket_date  basket_count
# 0         42366585    41475073  2019-06-19             2
# 1         35956841    43279538  2019-06-19             2
# 2         26139578    31715598  2019-06-19             3
# 3          3262253    47880260  2019-06-19             2
# 4         20056678    44747002  2019-06-19             2
# ...            ...         ...         ...           ...
# 14995      8336862    50977318  2019-05-26             2
# 14996      9500785    43862061  2019-05-26             2
# 14997     22787344     6041664  2019-05-26             2
# 14998      8221263     3597369  2019-05-26             2
# 14999      4912577    46646893  2019-05-26             2
#
# [15000 rows x 4 columns]

# %%
df_2["product_id"].value_counts()
# Out:
# product_id
# 43524799    32
# 31516269    25
# 39833031    24
# 46130148    17
# 40276011    12
#             ..
# 40160594     1
# 6192154      1
# 4231184      1
# 48559699     1
# 32661392     1
# Name: count, Length: 13161, dtype: int64
