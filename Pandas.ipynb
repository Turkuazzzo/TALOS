# %% [markdown]
# **Pandas**

# %% [markdown]
# *Creating a Data*

# %%
# pandas kütüphanesini import edelim

import pandas as pd

# %%
# Kendi verilerimizle dataframe oluşturma

df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]])

df
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
# sütun isimlendirme , columns = ["","",""]

df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]] , columns = ["A", "B", "C"])

df
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
# sütunların isimlerini görme

df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
# index isimlendirme , index = ["","",""]

df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]] , columns = ["A", "B", "C"], index = ["x","y","z"])

df
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
df.index
# Out:
# Index(['x', 'y', 'z'], dtype='object')

# %%
df.info # info fonksiyonu df DataFrame'i ile çalışır
        # bu durum hakkında bilgi verir
# Out:
# <bound method DataFrame.info of    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9>

# %%
df.info() # info fonksiyonunu direkt çalıştırır

# non-null count -> boş olmayan değerlerin sayısı
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, x to z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 204.0+ bytes

# %%
df.describe()

# temel istatistik
# sayısı
# ortalaması
# standart sapması
# minimumu
# yüzdelik değerleri
# maksimum
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
# sütunlardaki farklı değerlerin sayısı

df.nunique()
# Out:
# A    3
# B    3
# C    3
# dtype: int64

# %%
# sütunlardaki farklı tüm değerleri gösterir

df["A"].unique()
# Out:
# array([1, 4, 7])

# %%
# dataframe boyutu

df.shape
# Out:
# (3, 3)

# %%
df.shape()

# shape özellik çağırdığından metod değildir
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.size # 3x3 tipinde tablo 9 elemana sahip
# Out:
# 9

# %% [markdown]
# *Data Reading*

# %%
coffee = pd.read_csv("D:\\Kütüphane\\Python\\Datasets\\coffee.csv")

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
results = pd.read_parquet("D:\\Kütüphane\\Python\\Datasets\\results.parquet")

# %%
results.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None
# 4           1  FRA  Jacques Brugnon    4.0  False  None

# %%
olympics = pd.read_excel("D:\\Kütüphane\\Python\\Datasets\\olympics-data.xlsx")

# %%
olympics.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
# hız : parquet > csv > xlsx
# aynı verinin boyutları : 20mb < 200mb < büyük

# %%
bios = pd.read_csv("D:\\Kütüphane\\Python\\Datasets\\bios.csv")

# %%
# dosya tipi dönüştürme

bios.to_excel
bios.to_parquet

# %%
print(bios.head()) # 5
print(bios.head(2)) # 2
print(bios.tail()) # 5
print(bios.tail(2)) # 2
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25
#    athlete_id                   name   born_date born_city born_region  \
# ...

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %% [markdown]
# *Data Access*

# %%
coffee.loc[0] # 0. indeks
# Out:
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object

# %%
coffee.loc[0][1] # 0. indeksin 1. özelliği (feature)
# Out:
# C:\Users\90534\AppData\Local\Temp\ipykernel_27664\2866999467.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coffee.loc[0][1]
# 'Espresso'

# %%
coffee.loc[[0,1,2]] # 0, 1 ve 2. indeksler
# Out:
#        Day Coffee Type  Units Sold
# 0   Monday    Espresso          25
# 1   Monday       Latte          15
# 2  Tuesday    Espresso          30

# %%
coffee.loc[[0,1,2],["Day","Coffee Type"]] # 0, 1 ve 2. indekslerin belli sütunları
# Out:
#        Day Coffee Type
# 0   Monday    Espresso
# 1   Monday       Latte
# 2  Tuesday    Espresso

# %%
coffee.loc[1:10:2] # 1 'den 10 'a kadar 2 'şer atlayarak indeksleri göster
# Out:
#          Day Coffee Type  Units Sold
# 1     Monday       Latte          15
# 3    Tuesday       Latte          20
# 5  Wednesday       Latte          25
# 7   Thursday       Latte          30
# 9     Friday       Latte          35

# %%
coffee.loc[1:10:2, "Units Sold"]
# Out:
# 1    15
# 3    20
# 5    25
# 7    30
# 9    35
# Name: Units Sold, dtype: int64

# %%
coffee.loc[:, "Units Sold"] # Hepsini seçer
# Out:
# 0     25
# 1     15
# 2     30
# 3     20
# 4     35
# 5     25
# 6     40
# 7     30
# 8     45
# 9     35
# 10    45
# 11    35
# 12    45
# 13    35
# Name: Units Sold, dtype: int64

# %%
# spesifik bi veriye index metodu ile erişme

coffee.index = coffee["Day"]

# %%
coffee.head() # indexler "Day" sütunu ile aynı hale gelir
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso          25
# Monday        Monday       Latte          15
# Tuesday      Tuesday    Espresso          30
# Tuesday      Tuesday       Latte          20
# Wednesday  Wednesday    Espresso          35

# %%
coffee.loc["Monday"]
# Out:
#            Day Coffee Type  Units Sold
# Day
# Monday  Monday    Espresso          25
# Monday  Monday       Latte          15

# %%
coffee.loc["Wednesday"]
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Wednesday  Wednesday    Espresso          35
# Wednesday  Wednesday       Latte          25

# %%
coffee.loc["Monday":"Wednesday","Units Sold"]  # monday ve wednesday 'i time verisi olarak değil alfabede önceliğe göre sıralandırdığı için 
                                               # monday ve wednesday aralığı arasındaki Units Sold değerlerini döndürdü
# Out:
# Day
# Monday       25
# Monday       15
# Tuesday      30
# Tuesday      20
# Wednesday    35
# Wednesday    25
# Name: Units Sold, dtype: int64

# %%
coffee.loc[1:5]
# Out:
#          Day Coffee Type  Units Sold
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35
# 5  Wednesday       Latte          25

# %%
coffee = coffee.reset_index(drop=True) # indexi normal hale resetler ve "Day" kolonunu indekslemeden droplar (yoksa bi tane daha day kolonu olacaktı)
                                       # ya da baştan df ataması yapılır

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee.iloc[1]
# Out:
# Day            Monday
# Coffee Type     Latte
# Units Sold         15
# Name: 1, dtype: object

# %%
coffee.sort_values("Units Sold") # integerleri sıralar
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          15
# 3     Tuesday       Latte          20
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 13     Sunday       Latte          35
# 11   Saturday       Latte          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
coffee.sort_values("Units Sold", ascending=False) # integerleri büyükten küçüğe sıralar
# Out:
#           Day Coffee Type  Units Sold
# 10   Saturday    Espresso          45
# 8      Friday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 9      Friday       Latte          35
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 3     Tuesday       Latte          20
# 1      Monday       Latte          15

# %%
for index, row in coffee.iterrows():   # iterrows() -> (index,row)
    print(index, row["Units Sold"])
    ("\n\n\n\n")                       # spesifik veriye iterrows metodu ile erişme
# Out:
# 0 25
# 1 15
# 2 30
# 3 20
# 4 35
# 5 25
# 6 40
# 7 30
# 8 45
# 9 35
# 10 45
# 11 35
# 12 45
# 13 35

# %% [markdown]
# *Data Filtering*

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.1+ MB

# %%
bios[bios["height_cm"] > 180]
# Out:
#         athlete_id               name   born_date        born_city  \
# 1                2     Arnaud Boetsch  1969-04-01           Meulan
# 2                3       Jean Borotra  1898-08-13         Biarritz
# 5                6  Nicolas Chatelain  1970-01-13           Amiens
# 16              17         Guy Forget  1965-01-04       Casablanca
# 25              26      Henri Leconte  1963-07-04          Lillers
# ...            ...                ...         ...              ...
# 145465      149192  Stanislav Galiyev  1992-01-17  Moskva (Moscow)
# 145466      149193     Mikkel Aagaard  1995-10-18    Frederikshavn
# 145468      149195  Justin Abdelkader  1987-02-25         Muskegon
# 145473      149200     Toms Andersons  1993-11-25             Rīga
# 145494      149221      George Wright  1890-07-21          Toronto
#
#                  born_region born_country            NOC  height_cm  \
# 1                   Yvelines          FRA         France      183.0
# ...

# %%
bios.loc[bios["height_cm"] > 180 , ["name"]]  # belli filtrede olan indekslerin belli sütununu göstermesini istersem
# Out:
#                      name
# 1          Arnaud Boetsch
# 2            Jean Borotra
# 5       Nicolas Chatelain
# 16             Guy Forget
# 25          Henri Leconte
# ...                   ...
# 145465  Stanislav Galiyev
# 145466     Mikkel Aagaard
# 145468  Justin Abdelkader
# 145473     Toms Andersons
# 145494      George Wright
#
# [35368 rows x 1 columns]

# %%
bios[(bios["height_cm"] > 200) & (bios["born_country"] == "USA")]
# Out:
#         athlete_id             name   born_date     born_city     born_region  \
# 5197          5216     Anne Donovan  1961-11-01     Ridgewood      New Jersey
# 5652          5675      Mike Bantom  1951-12-03  Philadelphia    Pennsylvania
# 5657          5680       Jim Barnes  1941-04-13     Tuckerman        Arkansas
# 5681          5704     Walt Bellamy  1937-07-24      New Bern  North Carolina
# 5709          5732       Larry Bird  1956-12-07   French Lick         Indiana
# ...            ...              ...         ...           ...             ...
# 143706      147361      Bam Adebayo  1997-07-18        Newark      New Jersey
# 143707      147362     Jerami Grant  1994-03-12      Portland          Oregon
# 143710      147365  Khris Middleton  1991-08-12    Charleston  South Carolina
# 143712      147367     JaVale McGee  1988-01-19         Flint        Michigan
# 143733      147388       Nick Allen  1998-10-08     San Diego      California
#
# ...

# %%
bios[bios["born_country"] == "TR"]
# Out:
# Empty DataFrame
# Columns: [athlete_id, name, born_date, born_city, born_region, born_country, NOC, height_cm, weight_kg, died_date]
# Index: []

# %%
bios["born_country"].value_counts()
# Out:
# born_country
# USA       9641
# GER       6891
# GBR       5792
# FRA       5143
# ITA       4709
#           ...
# SEY          1
# SMT          1
# COK          1
# Corfu        1
# Aarhus       1
# Name: count, Length: 236, dtype: int64

# %%
bios[bios["height_cm"] < 215][["name"]]
# Out:
#                        name
# 1            Arnaud Boetsch
# 2              Jean Borotra
# 3           Jacques Brugnon
# 5         Nicolas Chatelain
# 6             Patrick Chila
# ...                     ...
# 145494        George Wright
# 145495    Polina Luchnikova
# 145496  Valeriya Merkusheva
# 145497      Yuliya Smirnova
# 145498       André Foussard
#
# [106604 rows x 1 columns]

# %%
print(bios[bios["height_cm"] < 215][["name","height_cm"]])
# Out:
#                        name  height_cm
# 1            Arnaud Boetsch      183.0
# 2              Jean Borotra      183.0
# 3           Jacques Brugnon      168.0
# 5         Nicolas Chatelain      181.0
# 6             Patrick Chila      180.0
# ...                     ...        ...
# 145494        George Wright      183.0
# 145495    Polina Luchnikova      167.0
# 145496  Valeriya Merkusheva      168.0
# 145497      Yuliya Smirnova      163.0
# 145498       André Foussard      166.0
#
# [106604 rows x 2 columns]

# %%
bios[bios["name"].str.contains("keith", case=False)]
# Out:
#         athlete_id                  name   born_date         born_city  \
# 1897          1907          Keith Hanlon  1966-09-01               NaN
# 3505          3517         Keith Wallace  1961-03-29           Preston
# 6228          6255         Keith Hartley  1940-10-15         Vancouver
# 8898          8946           Keith Mwila  1966-01-01               NaN
# 12053        12118          Keith Hervey  1898-11-03            Fulham
# ...            ...                   ...         ...               ...
# 109900      111105     Keith Cumberpatch  1927-08-25      Christchurch
# 115973      117348       Keith Sanderson  1975-02-02          Plymouth
# 117676      119195          Duncan Keith  1983-07-16          Winnipeg
# 122121      124176        Keith Ferguson  1979-09-07              Sale
# 127310      129749  Tracy Keith-Matchitt  1990-03-30  Palmerston North
#
#               born_region born_country            NOC  height_cm  weight_kg  \
# ...

# %%
bios[bios['name'].str.contains('keith|patrick', case=False)]
# Out:
#         athlete_id               name   born_date              born_city  \
# 6                7      Patrick Chila  1969-11-27            Ris-Orangis
# 119            120   Patrick Wheatley  1899-01-20                Vryheid
# 319            320  Patrick De Koning  1961-04-23            Dendermonde
# 1897          1907       Keith Hanlon  1966-09-01                    NaN
# 2115          2125       Patrick Jopp  1962-01-08                    NaN
# ...            ...                ...         ...                    ...
# 143975      147633  Patrick Chinyemba  2001-01-03                    NaN
# 144172      147850      Patrick Jakob  1996-10-17  Sankt Johann in Tirol
# 144547      148239  Patrick Galbraith  1986-03-11              Haderslev
# 144565      148257    Patrick Russell  1993-01-04               Gentofte
# 145435      149158  Patrick Gasienica  1998-11-28                McHenry
#
#             born_region born_country            NOC  height_cm  weight_kg  \
# ...

# %%
bios[bios['name'].str.contains('keith|patrick| De ', case=False)]
# Out:
#         athlete_id                      name   born_date          born_city  \
# 6                7             Patrick Chila  1969-11-27        Ris-Orangis
# 9               10        Guy de la Chapelle  1868-07-16  Farges-Allichamps
# 10              11   Élie, Comte de Lastours  1874-08-12            Orgeval
# 29              30  Édouard Mény de Marangue  1882-11-30          Paris VIe
# 119            120          Patrick Wheatley  1899-01-20            Vryheid
# ...            ...                       ...         ...                ...
# 144959      148668            Glenn de Blois  1995-09-05              Delft
# 144960      148669          Michelle de Jong  1999-07-06         Heerenveen
# 145278      148999             Almida de Val  1997-09-12            Angered
# 145299      149021          Jacob de la Rose  1995-05-20             Arvika
# 145435      149158         Patrick Gasienica  1998-11-28            McHenry
#
# ...

# %%
# Other cool regex filters

# Find athletes born in cities that start with a vowel:
vowel_cities = bios[bios['born_city'].str.contains(r'^[AEIOUaeiou]', na=False)]

# Find athletes with names that contain exactly two vowels:
two_vowels = bios[bios['name'].str.contains(r'^[^AEIOUaeiou]*[AEIOUaeiou][^AEIOUaeiou]*[AEIOUaeiou][^AEIOUaeiou]*$', na=False)]

# Find athletes with names that have repeated consecutive letters (e.g., "Aaron", "Emmett"):
repeated_letters = bios[bios['name'].str.contains(r'(.)\1', na=False)]

# Find athletes with names ending in 'son' or 'sen':
son_sen_names = bios[bios['name'].str.contains(r'son$|sen$', case=False, na=False)]

# Find athletes born in a year starting with '19':
born_19xx = bios[bios['born_date'].str.contains(r'^19', na=False)]

# Find athletes with names that do not contain any vowels:
no_vowels = bios[bios['name'].str.contains(r'^[^AEIOUaeiou]*$', na=False)]

# Find athletes whose names contain a hyphen or an apostrophe:
hyphen_apostrophe = bios[bios['name'].str.contains(r"[-']", na=False)]

# Find athletes with names that start and end with the same letter:
start_end_same = bios[bios['name'].str.contains(r'^(.).*\1$', na=False, case=False)]

# Find athletes with a born_city that has exactly 7 characters:
city_seven_chars = bios[bios['born_city'].str.contains(r'^.{7}$', na=False)]

# Find athletes with names containing three or more vowels:
three_or_more_vowels = bios[bios['name'].str.contains(r'([AEIOUaeiou].*){3,}', na=False)]

# %%
two_vowels = bios[bios['name'].str.contains(r'^[^AEIOUaeiou]*[AEIOUaeiou][^AEIOUaeiou]*[AEIOUaeiou][^AEIOUaeiou]*$', na=False)]

two_vowels
# Out:
#         athlete_id           name   born_date    born_city     born_region  \
# 12              13      J. Defert         NaN          NaN             NaN
# 30              31  André Prévost  1875-02-28  Paris VIIIe           Paris
# 68              69      Sam Smith  1971-11-27       Epping         England
# 70              71     Ruth Winch  1870-08-25         Ryde         England
# 73              74     Sky Andrew  1962-03-31       Newham         England
# ...            ...            ...         ...          ...             ...
# 145340      149062     A. J. Hurt  2000-12-05      Truckee      California
# 145349      149072      Kris Horn  1994-04-25     Weymouth   Massachusetts
# 145382      149105  Dylan Walczyk  1993-06-25    Rochester        New York
# 145452      149177     Radek Rýdl  2001-07-15    Jilemnice  Liberecký kraj
# 145483      149210        Feng He  2004-03-31          NaN             NaN
#
# ...

# %%
bios[bios['born_country'].isin(["USA", "FRA", "GBR"]) & (bios['name'].str.startswith("Keith"))]
# Out:
#         athlete_id                name   born_date             born_city  \
# 3505          3517       Keith Wallace  1961-03-29               Preston
# 12053        12118        Keith Hervey  1898-11-03                Fulham
# 14577        14674      Keith Harrison  1933-03-28            Birmingham
# 16166        16281      Keith Reynolds  1963-12-25              Solihull
# 18734        18862      Keith Sinclair  1945-06-26            Sunderland
# 29897        30123       Keith Langley  1961-06-03             Aldershot
# 34011        34275        Keith Remfry  1947-11-17                Ealing
# 46885        47234        Keith Collin  1937-01-18            Marylebone
# 50929        51288        Keith Carter  1924-08-30                 Akron
# 51185        51544       Keith Russell  1948-01-15                  Mesa
# 52913        53288      Keith Erickson  1944-04-19         San Francisco
# 55317        55712        Keith Boxell  1958-05-06               Clapham
# ...

# %%
bios.query("born_country == 'USA' and born_city =='Seattle'")
# Out:
#         athlete_id                   name   born_date born_city born_region  \
# 11030        11088          David Halpern  1955-08-18   Seattle  Washington
# 12800        12870            Todd Trewin  1958-04-20   Seattle  Washington
# 15476        15583         Scott McKinley  1968-10-15   Seattle  Washington
# 29079        29293            Joyce Tanac  1950-09-27   Seattle  Washington
# 31135        31371        Bill Kuhlemeier  1908-01-14   Seattle  Washington
# ...            ...                    ...         ...       ...         ...
# 133392      136331          Hans Struzyna  1989-03-31   Seattle  Washington
# 135448      138662  Maude Davis Crossland  2003-03-19   Seattle  Washington
# 136993      140229        Jenell Berhorst  2003-12-13   Seattle  Washington
# 143507      147159         Nevin Harrison  2002-06-02   Seattle  Washington
# 145446      149169       Corinne Stoddard  2001-08-15   Seattle  Washington
#
# ...

# %%
filtered_bios = bios[(bios["born_region"] == "New Hampshire") | (bios["born_city"] == "San Francisco")]

filtered_bios.head()
# Out:
#        athlete_id                 name   born_date      born_city  \
# 6128         6155  Raúl García-Ordóñez  1924-09-15      Littleton
# 7290         7329            Jim Walsh  1930-08-29  San Francisco
# 8619         8666      George Finnegan  1881-09-28  San Francisco
# 8639         8686         Frank Haller  1883-01-06  San Francisco
# 10981       11038       DeAnne Hemmens  1964-07-02  San Francisco
#
#          born_region born_country            NOC  height_cm  weight_kg  \
# 6128   New Hampshire          USA           Cuba      188.0        NaN
# 7290      California          USA  United States      193.0       86.0
# 8619      California          USA  United States        NaN        NaN
# 8639      California          USA  United States        NaN        NaN
# 10981     California          USA  United States        NaN        NaN
#
#         died_date
# 6128   2013-05-03
# 7290   1976-03-04
# 8619   1913-02-28
# 8639   1939-04-30
# 10981         NaN

# %%
bios.columns
# Out:
# Index(['athlete_id', 'name', 'born_date', 'born_city', 'born_region',
#        'born_country', 'NOC', 'height_cm', 'weight_kg', 'died_date'],
#       dtype='object')

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %% [markdown]
# *Sütundaki verileri tekrar bir dataframe altında toplama*

# %%
import datetime as dt

bios["born_date"] = pd.to_datetime(bios["born_date"])
bios["month_born"] = bios["born_date"].dt.month
bios["year_born"] = bios["born_date"].dt.year

# %%
bios.groupby([bios['year_born'],bios['month_born']])['name'].count().reset_index().sort_values('name', ascending=False)
# Out:
#       year_born  month_born  name
# 1437     1970.0         1.0   239
# 1461     1972.0         1.0   229
# 1629     1986.0         1.0   227
# 1497     1975.0         1.0   227
# 1617     1985.0         1.0   225
# ...         ...         ...   ...
# 51       1852.0         5.0     1
# 52       1852.0         6.0     1
# 1882     2008.0         7.0     1
# 1883     2008.0         8.0     1
# 1884     2009.0         1.0     1
#
# [1885 rows x 3 columns]

# %%
pip install pyjanitor --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
import janitor

coffee.clean_names()
# Out:
#           day coffee_type  units_sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
pip install skimpy --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from skimpy import skim

skim(bios)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 145500 │ │ string      │ 7     │                                                          │
# │ │ Number of columns │ 10     │ │ float64     │ 2     │                                                          │
# │ └───────────────────┴────────┘ │ int64       │ 1     │                                                          │
# ...

# %% [markdown]
# *bios datasetindeki na değerlerini dolduralım veya satırlarını kaldıralım*

# %%
bios["weight_kg"].fillna(bios["weight_kg"].mean())
# Out:
# 0         71.890996
# 1         76.000000
# 2         76.000000
# 3         64.000000
# 4         71.890996
#             ...
# 145495    61.000000
# 145496    65.000000
# 145497    55.000000
# 145498    71.890996
# 145499    71.890996
# Name: weight_kg, Length: 145500, dtype: float64

# %%
skim(bios)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 145500 │ │ string      │ 6     │                                                          │
# │ │ Number of columns │ 12     │ │ float64     │ 4     │                                                          │
# │ └───────────────────┴────────┘ │ int64       │ 1     │                                                          │
# ...
